# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Simple linear regression
#
# y = b0 + b1X1
#
# y => dependent variable
# b0 => y intercept
# b1 => slope coefficient
# X1 => independent variable

# %%
data = {"X" : [1,2,3,4,5,6,7],
        "y" : [1.5,3.8,6.7,9.0,11.2,13.6,16.0]}
data
# Out:
# {'X': [1, 2, 3, 4, 5, 6, 7], 'y': [1.5, 3.8, 6.7, 9.0, 11.2, 13.6, 16.0]}

# %%
df = pd.DataFrame(data)

# %%
plt.scatter(df.X,df.y)
plt.xlabel("X")
plt.ylabel("y");

# %%
## Splitting data into X(independent variables) and y(target)

X = df.drop("y",axis=1)
y = df.y

# %%
## Splitting data into train and test

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y,
                                                 test_size=0.2)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((5, 1), (2, 1), (5,), (2,))

# %%
from sklearn.linear_model import LinearRegression

Regressor = LinearRegression()

Regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Predicting results 

y_preds = Regressor.predict(X_test)
y_preds
# Out:
# array([ 8.80689655, 13.64137931])

# %%
## Evaluating the model

Regressor.score(X_test,y_test)
# Out:
# 0.9963136872343438

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.scatter(X_test,y_test,color="r",label="test points")
plt.plot(X_train,Regressor.predict(X_train),color="g",label="trained")
plt.legend();

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

print("Mean absolute error : " ,mean_absolute_error(y_test,y_preds))
print("Mean squared error :  ",mean_squared_error(y_test,y_preds))
# Out:
# Mean absolute error :  0.11724137931034395
# Mean squared error :   0.019500594530321165

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
Regressor.predict([[12]]) # Single prediction
# Out:
# array([28.14482759])

# %% [markdown]
# ## Least squared error
#
# Sum of residuals minimized

# %%
sum((y_test - y_preds)**2)  # (y_actual - y_pred)^2 -> Residuals
# Out:
# 0.03900118906064233

# %%
Regressor.coef_ , Regressor.intercept_
# Out:
# (array([2.41724138]), -0.8620689655172411)

# %% [markdown]
# The equation,
#
# y = c     +   m     x
#
# y = -0.86 + 2.41x
